# %%
from langchain_core.messages import HumanMessage
from psychscanner import ExpCard, ExpCardInit, ScannerModel
from psychscanner.parsers import (
    list_parsers,
    get_parser,
    ResponseRmStEI,
    AllResponseRMEI,
)
from psychscanner.datasets.prompts.parser_tasks import (
    Response_part_1_rm,
    Response_part_2_rm,
)

# %%
MODEL_NAME   = 'smollm2:360m-instruct-fp16'
MODEL_FAMILY = 'ollama'
# ──────────────────────────────────────────────────────────────────────────────

task_files = {
    'singleturn'  : TASKS_DIR / 'rm_singleturn_demo.json',
    'trialchain'  : TASKS_DIR / 'rm_trialchain_demo.json',
    'episodic'    : TASKS_DIR / 'rm_episodic_demo.json',
    'episodic_fb' : TASKS_DIR / 'rm_episodic_fb_demo.json',
}
for name, p in task_files.items():
    print(f'  {name:13} -> {p.name}  (exists={p.exists()})')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       2 MODEL_FAMILY = 'ollama'
#       3 # ──────────────────────────────────────────────────────────────────────────────
#       5 task_files = {
# ----> 6     'singleturn'  : TASKS_DIR / 'rm_singleturn_demo.json',
#       7     'trialchain'  : TASKS_DIR / 'rm_trialchain_demo.json',
#       8     'episodic'    : TASKS_DIR / 'rm_episodic_demo.json',
#       9     'episodic_fb' : TASKS_DIR / 'rm_episodic_fb_demo.json',
#      10 }
#      11 for name, p in task_files.items():
#      12     print(f'  {name:13} -> {p.name}  (exists={p.exists()})')
#
# NameError: name 'TASKS_DIR' is not defined
